# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# %%
def CreateSphere(N, R):
    
    X = np.zeros(N)
    Y = np.zeros_like(X)
    Z = np.zeros_like(X)
    
    
    for i in tqdm(range(N)):
        
        u = np.random.rand()
        ro = R*u**(1/2)
        
        theta = np.random.uniform(0,2*np.pi)
        phi = np.random.uniform(0,np.pi)
        
        X[i] = ro*np.sin(phi)*np.cos(theta)
        Y[i] = ro*np.sin(phi)*np.sin(theta)
        Z[i] = ro*np.cos(phi)
    
    
    return X,Y,Z

# %%
X,Y,Z = CreateSphere( int(1e6), 1 )
# Out:
# 100%|██████████| 1000000/1000000 [00:12<00:00, 77490.62it/s]

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1, projection = '3d')

#configurar límites de los ejes
ax.set_xlim3d(-1, 1)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)

ax.view_init(10, 60)

ax.scatter(X,Y,Z,color='b')
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
def f(r):
    func = np.exp(r)
    return  func

# %%
def GetPoints(R):
    
    u = np.random.rand()
    r = R*u**(1/2)

    
    return r

# %%
N = int(1e6)
Sample = np.zeros(N)

for i in range(N):
    r = GetPoints(1)
    Sample[i] = f(r)

# %%
Integral = 2*np.pi**2*np.average( Sample )

# %%
print(Integral, 4*np.pi*(np.exp(1)-2))
# Out:
# 39.471563578554935 9.02619566197592

# %%
Sample
# Out:
# array([ 1.92822717,  0.18346093,  2.16896851, ...,  1.09079335,
#        -1.63748266,  0.43778557])
